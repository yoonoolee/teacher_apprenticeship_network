# %% [markdown]
# # TESTING STUFF
#
# Reads data from Box Drive. Uses `box_utils.py` (in this repo) to auto-detect
# each collaborator's local Box Drive folder, so no one has to hardcode a path.

# %%
from box_utils import BOX_ROOT
print("Using Box root:", BOX_ROOT)

# %%
data_path = BOX_ROOT / "OPD & TAN - Core Workspace" / "Praxis Sprint Feedback Survey — Teacher Apprenticeship Network (Responses).xlsx"

import pandas as pd
df = pd.read_excel(data_path)
print(df.shape)
df.head()
